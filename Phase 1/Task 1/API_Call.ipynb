# %%
import pandas as pd
import requests
import json

# %%
api_url = "https://api.binance.com/api/v3/ticker/24hr"

# %%
response = requests.get(api_url)
data = json.loads(response.text)

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#     symbol  priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC  -0.00078000             -1.407       0.05477103     0.05544000
# 1   LTCBTC  -0.00002700             -1.244       0.00214221     0.00216900
# 2   BNBBTC  -0.00009600             -1.287       0.00739117     0.00746200
# 3   NEOBTC  -0.00001200             -5.013       0.00023359     0.00023950
# 4  QTUMETH  -0.00002900             -2.100       0.00136511     0.00138300
#
#     lastPrice      lastQty    bidPrice       bidQty    askPrice  ...  \
# 0  0.05467000   0.00990000  0.05467000  32.71450000  0.05468000  ...
# 1  0.00214400   4.15500000  0.00214300  72.52900000  0.00214400  ...
# 2  0.00736600   0.11400000  0.00736500   3.81900000  0.00736600  ...
# 3  0.00022740  30.86000000  0.00022730  16.58000000  0.00022740  ...
# 4  0.00135200   9.90000000  0.00135300  47.20000000  0.00135800  ...
#
#     openPrice   highPrice    lowPrice          volume    quoteVolume  \
# 0  0.05545000  0.05545000  0.05429000  29795.85490000  1631.94961237
# 1  0.00217100  0.00217400  0.00212000  27327.59200000    58.54143539
# 2  0.00746200  0.00746300  0.00729100  22116.32900000   163.46546049
# 3  0.00023940  0.00024050  0.00022740  17767.35000000     4.15026014
# 4  0.00138100  0.00139100  0.00135200    540.70000000     0.73811400
#
#         openTime      closeTime    firstId     lastId  count
# 0  1697652456300  1697738856300  424060805  424091931  31127
# 1  1697652455555  1697738855555   93815456   93823546   8091
# 2  1697652449159  1697738849159  227874497  227900247  25751
# 3  1697652456218  1697738856218   45561551   45562913   1363
# 4  1697652364404  1697738764404    5404028    5404056     29
#
# [5 rows x 21 columns]

# %%
df.to_csv("binance_24hr_ticker_data.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2322 entries, 0 to 2321
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   symbol              2322 non-null   object
#  1   priceChange         2322 non-null   object
#  2   priceChangePercent  2322 non-null   object
#  3   weightedAvgPrice    2322 non-null   object
#  4   prevClosePrice      2322 non-null   object
#  5   lastPrice           2322 non-null   object
#  6   lastQty             2322 non-null   object
#  7   bidPrice            2322 non-null   object
#  8   bidQty              2322 non-null   object
#  9   askPrice            2322 non-null   object
#  10  askQty              2322 non-null   object
#  11  openPrice           2322 non-null   object
#  12  highPrice           2322 non-null   object
#  13  lowPrice            2322 non-null   object
#  14  volume              2322 non-null   object
#  15  quoteVolume         2322 non-null   object
#  16  openTime            2322 non-null   int64
#  17  closeTime           2322 non-null   int64
#  18  firstId             2322 non-null   int64
#  19  lastId              2322 non-null   int64
#  20  count               2322 non-null   int64
# dtypes: int64(5), object(16)
# memory usage: 381.1+ KB
